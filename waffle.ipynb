# %% [markdown]
# <a href="https://colab.research.google.com/github/rodolforicardotech/trainning-data-viz/blob/main/waffle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import calmap
import numpy as np

# %%
df = pd.read_csv('waffle.csv')

# %%
df
# Out:
#           date  frequency
# 0   01/01/2022          0
# 1   01/02/2022          0
# 2   01/03/2022          1
# 3   01/04/2022          1
# 4   01/05/2022          1
# 5   01/06/2022          0
# 6   01/07/2022          1
# 7   01/08/2022          0
# 8   01/09/2022          1
# 9   01/10/2022          0
# 10  01/11/2022          1
# 11  01/12/2022          1
# 12  01/13/2022          1
# 13  01/14/2022          1
# 14  01/15/2022          0

# %%
#change the type of data
df['date'] = pd.to_datetime(df['date'])
#Set orderdate as index
df.set_index('date', inplace = True)

# %%
df
# Out:
#             frequency
# date
# 2022-01-01          0
# 2022-01-02          0
# 2022-01-03          1
# 2022-01-04          1
# 2022-01-05          1
# 2022-01-06          0
# 2022-01-07          1
# 2022-01-08          0
# 2022-01-09          1
# 2022-01-10          0
# 2022-01-11          1
# 2022-01-12          1
# 2022-01-13          1
# 2022-01-14          1
# 2022-01-15          0

# %%
chart = calplot.calplot(data = df['frequency'], how = 'sum', cmap='Purples', figsize = (16, 8), suptitle = "Dias que comi fruta")
